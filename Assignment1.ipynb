# %%
lst=['priyanka',10,27.5,[1,2,3,4]]
lst
# Out:
# ['priyanka', 10, 27.5, [1, 2, 3, 4]]

# %%
lst=['priyanka', 10,27.5]
lst.append("7138")
lst
# Out:
# ['priyanka', 10, 27.5, '7138']

# %%
lst=['priyanka', 10, 27.5, '7138']
lst.remove('7138')
lst
# Out:
# ['priyanka', 10, 27.5]

# %%
lst=['priyanka', 10, 27.5, '7138']
lst.extend("7138")
lst
# Out:
# ['priyanka', 10, 27.5, '7138', '7', '1', '3', '8']

# %%
lst=['priyanka', 10, 27.5, '7138']
lst. index(10)
# Out:
# 1

# %%
lst=['priyanka', 10, 27.5, '7138']
lst. count("priyanka")
# Out:
# 1

# %%
dit={"name":"priyanka" , "age":"20" , "hobbies":"listening music"}
dit
# Out:
# {'age': '20', 'hobbies': 'listening music', 'name': 'priyanka'}

# %%
 dit={"name":"priyanka","age":"20","hobbies":"listening music"} 
dit.get('name')
# Out:
# 'priyanka'

# %%
dit={"name":"priyanka","age":"20","hobbies":"listening music"}
dit. items()
# Out:
# dict_items([('name', 'priyanka'), ('age', '20'), ('hobbies', 'listening music')])

# %%
 dit={"name":"priyanka","age":"20","hobbies":"listening music"}
dit.keys()
# Out:
# dict_keys(['name', 'age', 'hobbies'])

# %%
 dit={"name":"priyanka","age":"20","hobbies":"listening music"}
dit. pop('name')
# Out:
# 'priyanka'

# %%
 dit={"name":"priyanka","age":"20","hobbies":"listening music"} 
dit.copy()
dit
# Out:
# {'age': '20', 'hobbies': 'listening music', 'name': 'priyanka'}

# %%
st={"kiran","python",1,2,3,4,5,5,6,6}
st
# Out:
# {1, 2, 3, 4, 5, 6, 'kiran', 'python'}

# %%
 st={"kiran","python",1,2,3,4,5,5,6,6}
st1={'kiran', 2}
st1.issubset(st)
# Out:
# True

# %%
 st={"kiran","python",1,2,3,4,5,5,6,6}
st. add("riya")
st
# Out:
# {1, 2, 3, 4, 5, 6, 'kiran', 'python', 'riya'}

# %%
 st={"kiran","python",1,2,3,4,5,5,6,6}
st. isdisjoint(st)
# Out:
# False

# %%
st={"kiran","python",1,2,3,4,5,5,6,6}
st1={"python",5}
st. intersection(st1)
# Out:
# {5, 'python'}

# %%
 st={"kiran","python",1,2,3,4,5,5,6,6}
 
st. copy()
# Out:
# {1, 2, 3, 4, 5, 6, 'kiran', 'python'}

# %%
tup=('youth', 'letsupgrade. in', 'python') 
tup
# Out:
# ('youth', 'letsupgrade. in', 'python')

# %%
 tup=('youth', '$', 'python') 
tup.count("$")
# Out:
# 1

# %%
 tup=('youth', 'hello', 'python') 
tup. index("hello")
# Out:
# 1

# %%
name="ram charan"
name1="allu arjun"
name
# Out:
# 'ram charan'

# %%
 name="ram charan"
name1="allu arjun"
name+name1
# Out:
# 'ram charanallu arjun'
