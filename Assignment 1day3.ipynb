# %%
num1=1000
num2=5000
if num1>=4500:
    print("safe to land")
elif num2>=1000:
    print("bring down to 1000")
else:
    print("turn around and try later")
# Out:
# bring down to 1000

# %%
 num1=1000
num2=5000
if num1>=1000:
    print("safe to land")
elif num2>=4500:
    print("bring down to 1000")
else:
    print("turn around and try later")
# Out:
# safe to land

# %%
 num1=1000
num2=5000
if num1>1000:
    print("safe to land")
elif num2>6000:
    print("bring down to 1000")
else:
    print("turn around and try later")
# Out:
# turn around and try later
